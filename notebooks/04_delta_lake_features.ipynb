# %% [markdown]
# ## Section 1: Time Travel

# %%
# %sql
DESCRIBE HISTORY nyc_taxi.gold.fact_trip;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select count(*) from nyc_taxi.gold.fact_trip version as of 0
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(*)</th></tr></thead><tbody><tr><td>7668647</td></tr></tbody></table></div>

# %% [markdown]
# Section 2: Optimize

# %%
# %sql
OPTIMIZE nyc_taxi.gold.fact_trip;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td></td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 0, null, null, 0, 0, 1, 1, true, 0, 0, 1782637893535, 1782637894085, 8, 0, null, List(0, 0), null, 9, 9, 0, 0, null, null)</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE DETAIL nyc_taxi.gold.fact_trip;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT COUNT(*)
FROM nyc_taxi.gold.fact_trip VERSION AS OF 2;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>7668647</td></tr></tbody></table></div>

# %%
fact_df = spark.table(
    "nyc_taxi.gold.fact_trip"
)

fact_df_limited = fact_df.limit(1000)

(
    fact_df_limited
    .write
    .format("delta")
    .mode("overwrite")
    .saveAsTable(
        "nyc_taxi.gold.fact_trip"
    )
)

# %%
# %sql
DESCRIBE HISTORY nyc_taxi.gold.fact_trip;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select count(*) from nyc_taxi.gold.fact_trip;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(*)</th></tr></thead><tbody><tr><td>7668647</td></tr></tbody></table></div>

# %%
# %sql
RESTORE TABLE nyc_taxi.gold.fact_trip VERSION AS OF 2
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>table_size_after_restore</th><th>num_of_files_after_restore</th><th>num_removed_files</th><th>num_restored_files</th><th>removed_files_size</th><th>restored_files_size</th></tr></thead><tbody><tr><td>57373479</td><td>1</td><td>1</td><td>1</td><td>16554</td><td>57373479</td></tr></tbody></table></div>

# %%
# %sql
ALTER TABLE nyc_taxi.gold.fact_trip
SET TBLPROPERTIES (
  'delta.enableChangeDataFeed' = 'true'
);

# %%
# %sql
SHOW TBLPROPERTIES nyc_taxi.gold.fact_trip;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
fact_df = spark.table("nyc_taxi.gold.fact_trip")

sample_df = fact_df.limit(5)

sample_df.write.mode("append").format("delta").saveAsTable("nyc_taxi.gold.fact_trip")

# %%
# %sql
DESCRIBE HISTORY nyc_taxi.gold.fact_trip
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT *
FROM table_changes(
  'nyc_taxi.gold.fact_trip',
  6
);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
OPTIMIZE nyc_taxi.gold.fact_trip
ZORDER BY (date_key);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td></td><td>List(1, 2, List(57597146, 57597146, 5.7597146E7, 1, 57597146), List(2986, 57373479, 2.86882325E7, 2, 57376465), 0, List(minCubeSize(107374182400), List(0, 0), List(2, 57376465), 0, List(2, 57376465), 1, null), null, 0, 1, 2, 0, false, 0, 0, 1782638720573, 1782638728469, 8, 1, null, List(0, 0), null, 9, 9, 3965, 0, null, null)</td></tr></tbody></table></div>
